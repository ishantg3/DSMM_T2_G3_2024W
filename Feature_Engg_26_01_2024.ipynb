# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
iris=sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.describe(include='O')
# Out:
#        species
# count      150
# unique       3
# top     setosa
# freq        50

# %%
sns.barplot(x='species',y='sepal_length',data=iris, color='Green')
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.scatterplot(x='sepal_length',y='sepal_width',data=iris)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.scatterplot(x='sepal_length',y='sepal_width',data=iris, hue='species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.distplot(iris['sepal_width'], kde=True, color='red')
# Out:
# <ipython-input-25-43f27a6eaffd>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(iris['sepal_width'], kde=True, color='red')
# <Axes: xlabel='sepal_width', ylabel='Density'>

# %%
plt.figure(figsize=(10,7))
sns.heatmap(iris.corr(), cmap='coolwarm', annot=True)
# Out:
# <ipython-input-30-d459b7ea444f>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(iris.corr(), cmap='coolwarm', annot=True)
# <Axes: >

# %%
plt.figure(figsize=(15,7))
sns.boxplot(x='species',y='petal_length',data=iris)
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
plt.figure(figsize=(15,7))
sns.boxplot(x='species',y='sepal_length',data=iris)
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
plt.figure(figsize=(15,7))
sns.boxplot(x='species',y='sepal_width',data=iris)
# Out:
# <Axes: xlabel='species', ylabel='sepal_width'>

# %%
plt.figure(figsize=(15,7))
sns.boxplot(x='species',y='petal_width',data=iris)
# Out:
# <Axes: xlabel='species', ylabel='petal_width'>

# %%
df=pd.read_excel('flight_price.xlsx')

# %%
df.head(30)
# Out:
#               Airline    Source Destination  Duration Total_Stops  Price date  \
# 0              IndiGo  Banglore   New Delhi       170    non-stop   3897   24
# 1           Air India   Kolkata    Banglore       445     2 stops   7662    1
# 2         Jet Airways     Delhi      Cochin      1140     2 stops  13882    9
# 3              IndiGo   Kolkata    Banglore       325      1 stop   6218   12
# 4              IndiGo  Banglore   New Delhi       285      1 stop  13302   01
# 5            SpiceJet   Kolkata    Banglore       145    non-stop   3873   24
# 6         Jet Airways  Banglore   New Delhi       930      1 stop  11087   12
# 7         Jet Airways  Banglore   New Delhi      1265      1 stop  22270   01
# 8         Jet Airways  Banglore   New Delhi      1530      1 stop  11087   12
# 9   Multiple carriers     Delhi      Cochin       470      1 stop   8625   27
# 10          Air India     Delhi      Cochin       795      1 stop   8907    1
# 11             IndiGo   Kolkata    Banglore       155    non-stop   4174   18
# 12          Air India   Chennai     Kolkata       135    non-stop   4667   24
# 13        Jet Airways   Kolkata    Banglore       730      1 stop   9663    9
# 14             IndiGo   Kolkata    Banglore       155    non-stop   4804   24
# 15          Air India     Delhi      Cochin      1595     2 stops  14011    3
# 16           SpiceJet     Delhi      Cochin       270      1 stop   5830   15
# 17        Jet Airways     Delhi      Cochin      1355      1 stop  10262   12
# 18          Air India     Delhi      Cochin      1380     2 stops  13381   12
# 19        Jet Airways     Delhi      Cochin      1235      1 stop  12898   27
# 20              GoAir     Delhi      Cochin       310      1 stop  19495    6
# 21          Air India  Banglore   New Delhi       920      1 stop   6955   21
# 22             IndiGo  Banglore       Delhi       170    non-stop   3943    3
# 23             IndiGo  Banglore       Delhi       175    non-stop   4823    1
# 24        Jet Airways   Kolkata    Banglore       800      1 stop   7757    6
# 25        Jet Airways     Delhi      Cochin       910     2 stops  13292    9
# 26             IndiGo     Delhi      Cochin       345      1 stop   8238    1
# 27              GoAir     Delhi      Cochin       355      1 stop   7682   15
# 28            Vistara  Banglore       Delhi       170    non-stop   4668   18
# 29            Vistara   Chennai     Kolkata       135    non-stop   3687   15
#
#    month  year Dep_hour Dep_mins Arrival_hour Arrival_mins
# 0     03  2019       22       20           01           10
# 1     05  2019       05       50           13           15
# 2     06  2019       09       25           04           25
# 3     05  2019       18       05           23           30
# 4     03  2019       16       50           21           35
# 5     06  2019       09       00           11           25
# 6     03  2019       18       55           10           25
# 7     03  2019       08       00           05           05
# 8     03  2019       08       55           10           25
# 9     05  2019       11       25           19           15
# 10    06  2019       09       45           23           00
# 11    04  2019       20       20           22           55
# 12    06  2019       11       40           13           55
# 13    05  2019       21       10           09           20
# 14    04  2019       17       15           19           50
# 15    03  2019       16       40           19           15
# 16    04  2019       08       45           13           15
# 17    06  2019       14       00           12           35
# 18    06  2019       20       15           19           15
# 19    05  2019       16       00           12           35
# 20    03  2019       14       10           19           20
# 21    03  2019       22       00           13           20
# 22    04  2019       04       00           06           50
# 23    05  2019       18       55           21           50
# 24    05  2019       18       55           08           15
# 25    06  2019       21       25           12           35
# 26    06  2019       21       50           03           35
# 27    05  2019       07       00           12           55
# 28    06  2019       09       45           12           35
# 29    06  2019       07       05           09           20

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
df.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %%
df['date']=df['Date_of_Journey'].str.split('/').str[0]
df['month']=df['Date_of_Journey'].str.split('/').str[1]
df['year']=df['Date_of_Journey'].str.split('/').str[2]

# %%
df.drop('Date_of_Journey',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Source           10683 non-null  object
#  2   Destination      10683 non-null  object
#  3   Route            10682 non-null  object
#  4   Dep_Time         10683 non-null  object
#  5   Arrival_Time     10683 non-null  object
#  6   Duration         10683 non-null  object
#  7   Total_Stops      10682 non-null  object
#  8   Additional_Info  10683 non-null  object
#  9   Price            10683 non-null  int64
#  10  date             10683 non-null  object
#  11  month            10683 non-null  object
#  12  year             10683 non-null  object
# dtypes: int64(1), object(12)
# memory usage: 1.1+ MB

# %%
df['Dep_hour']=df['Dep_Time'].str.split(':').str[0]
df['Dep_mins']=df['Dep_Time'].str.split(':').str[1]

# %%
df.drop('Dep_Time',axis=1,inplace=True)

# %%
df['Arrival_hour']=df['Arrival_Time'].str.split(' ').str[0].str.split(':').str[0]
df['Arrival_mins']=df['Arrival_Time'].str.split(' ').str[0].str.split(':').str[1]
df.drop('Arrival_Time',axis=1,inplace=True)

# %%
def convert_into_minutes(Duration):
  total_minutes=0
  for i in Duration.split():
    if 'h' in i:
      total_minutes+=int(i.replace('h',''))*60
    if 'm' in i:
      total_minutes+=int(i.replace('m',''))
  return total_minutes

# %%
df['Duration']=df['Duration'].apply(convert_into_minutes)

# %%
df.drop(['Additional_Info', 'Route'], axis=1, inplace=True)

# %%
df['Airline'].value_counts()
# Out:
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1752
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: Airline, dtype: int64

# %%
df['Airline']=df['Airline'].map({'Jet Airways':0, 'IndiGo':1, 'Air India':2, 'Multiple carriers':3, 'SpiceJet':4, 'Vistara':5, 'GoAir':6, 'Air Asia':7,'Multiple carriers Premium economy':3, 'Jet Airways Business':0, 'Vistara Premium economy':5, 'Trujet':4})

# %%
df['Source'].value_counts()
# Out:
# Delhi       4537
# Kolkata     2871
# Banglore    2197
# Mumbai       697
# Chennai      381
# Name: Source, dtype: int64

# %%
df['Source']=df['Source'].map({'Delhi':0, 'Kolkata':1, 'Banglore':2, 'Mumbai':3, 'Chennai':4})

# %%
df['Destination'].value_counts()
# Out:
# Cochin       4537
# Banglore     2871
# Delhi        1265
# New Delhi     932
# Hyderabad     697
# Kolkata       381
# Name: Destination, dtype: int64

# %%
df['Destination']=df['Destination'].map({'Cochin':0, 'Banglore':1, 'Delhi':2, 'New Delhi':3, 'Hyderabad':4})

# %%
df['Total_Stops'].value_counts()
# Out:
# 1 stop      5625
# non-stop    3491
# 2 stops     1520
# 3 stops       45
# 4 stops        1
# Name: Total_Stops, dtype: int64

# %%
df['Total_Stops']=df['Total_Stops'].map({'non-stop':0, '2 stops':2, '1 stop':1, '3 stops':3, '4 stops':4, 'nan':1})

# %%
df
# Out:
#        Airline  Source  Destination  Duration  Total_Stops  Price date month  \
# 0            1       2          3.0       170          0.0   3897   24    03
# 1            2       1          1.0       445          2.0   7662    1    05
# 2            0       0          0.0      1140          2.0  13882    9    06
# 3            1       1          1.0       325          1.0   6218   12    05
# 4            1       2          3.0       285          1.0  13302   01    03
# ...        ...     ...          ...       ...          ...    ...  ...   ...
# 10678        7       1          1.0       150          0.0   4107    9    04
# 10679        2       1          1.0       155          0.0   4145   27    04
# 10680        0       2          2.0       180          0.0   7229   27    04
# 10681        5       2          3.0       160          0.0  12648   01    03
# 10682        2       0          0.0       500          2.0  11753    9    05
#
#        year Dep_hour Dep_mins Arrival_hour Arrival_mins
# 0      2019       22       20           01           10
# 1      2019       05       50           13           15
# 2      2019       09       25           04           25
# 3      2019       18       05           23           30
# 4      2019       16       50           21           35
# ...     ...      ...      ...          ...          ...
# 10678  2019       19       55           22           25
# 10679  2019       20       45           23           20
# 10680  2019       08       20           11           20
# 10681  2019       11       30           14           10
# 10682  2019       10       55           19           15
#
# [10683 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Airline       10683 non-null  int64
#  1   Source        10683 non-null  int64
#  2   Destination   10302 non-null  float64
#  3   Duration      10683 non-null  int64
#  4   Total_Stops   10682 non-null  float64
#  5   Price         10683 non-null  int64
#  6   date          10683 non-null  int64
#  7   month         10683 non-null  int64
#  8   year          10683 non-null  int64
#  9   Dep_hour      10683 non-null  int64
#  10  Dep_mins      10683 non-null  int64
#  11  Arrival_hour  10683 non-null  int64
#  12  Arrival_mins  10683 non-null  int64
# dtypes: float64(2), int64(11)
# memory usage: 1.1 MB

# %%
df[['date', 'month', 'year', 'Dep_hour', 'Dep_mins', 'Arrival_hour', 'Arrival_mins']]=df[['date', 'month', 'year', 'Dep_hour', 'Dep_mins', 'Arrival_hour', 'Arrival_mins']].astype(int)
